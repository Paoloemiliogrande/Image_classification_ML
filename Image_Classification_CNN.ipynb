# %% [markdown]
# # QUESTO PER ORA È IL MODELLO MIGLIORE:
# - INPUT SHAPE 150x150
#
# Modello:
#
# - model.add(Conv2D(128, (3, 3), activation='relu', input_shape=(150, 150, 1)))
# - model.add(MaxPooling2D(2, 2))
# - model.add(Dropout(0.2))
# - model.add(Conv2D(64, (3, 3), activation='relu'))
# - model.add(MaxPooling2D(2, 2))
# - model.add(Dropout(0.2))
# - model.add(Conv2D(32, (3, 3), activation='relu'))
# - model.add(MaxPooling2D(2, 2))
# - model.add(Dropout(0.2))
# - model.add(Flatten())
# - model.add(Dense(256, activation='relu'))
# - model.add(Dense(5, activation='softmax'))

# %%
#importing libraries
import tqdm
from tqdm import tqdm
import os
from PIL import Image
import numpy as np

# %% [markdown]
# ## MODEL BUILDING

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from keras.regularizers import l1, l2

# %%
model = Sequential() #initializing model

# %%
#ADDING THE LAYERS 
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 1), kernel_regularizer=l2(0.001)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.5))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.001)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.5))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(0.001)))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(256, activation='relu',  kernel_regularizer=l2(0.001)))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))
# Out:
# /Users/joshuabrauner/Library/Python/3.9/lib/python/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.metrics import Precision, Recall, AUC

# %%
#compiling the model
OPTIM=Adam(learning_rate=0.001)

model.compile(optimizer= OPTIM, loss = 'categorical_crossentropy',
              metrics = [ "accuracy", 
                         Precision(name='precision'), 
                         Recall(name='recall'), 
                         AUC(name='auc')])

# %%
#display the model
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_10 (Conv2D)              │ (None, 148, 148, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 34, 34, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 17, 17, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 17, 17, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 36992)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │     9,470,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,563,908 (36.48 MB)
#  Trainable params: 9,563,908 (36.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # SPLITTING IN TRAIN AND TEST SET

# %%
#TRAIN E TEST SPLIT 
import os
import shutil
from sklearn.model_selection import train_test_split

# Assume `base_dir` is the path to the directory containing your 5 label subdirectories.
base_dir = '/Users/joshuabrauner/Desktop/Image classification/LABELLED IMAGES'
labels = ['advertisements', 'email', 'handwritten', 'resume']
file_paths = []
file_labels = []

# Create a list of file paths and labels
for label in labels:
    folder_path = os.path.join(base_dir, label)
    files = os.listdir(folder_path)
    for file in files:
        file_paths.append(os.path.join(folder_path, file))
        file_labels.append(label)

# Split the data
train_paths, test_paths, train_labels, test_labels = train_test_split(
    file_paths, 
    file_labels, 
    test_size=0.2, 
    stratify=file_labels
)

# Function to copy files to a new directory structure
def copy_files(file_paths, file_labels, dest_base_dir):
    for path, label in zip(file_paths, file_labels):
        # Create subdirectory with `label`
        dest_dir = os.path.join(dest_base_dir, label)
        if not os.path.exists(dest_dir):
            os.makedirs(dest_dir)
        # Copy file to the new directory
        shutil.copy(path, dest_dir)

# Define your new training and testing directories
train_dir = '/Users/joshuabrauner/Desktop/Train2'
test_dir = '/Users/joshuabrauner/Desktop/Test2'

# Copy the files to the new directories
copy_files(train_paths, train_labels, train_dir)
copy_files(test_paths, test_labels, test_dir)

# %%
# Define your training and testing directories
train_dir = '/Users/joshuabrauner/Desktop/Train2'
test_dir = '/Users/joshuabrauner/Desktop/Test2'

def count_files(directory):
    total_files = 0
    for root, dirs, files in os.walk(directory):
        total_files += len(files)
    return total_files

# Conteggio delle immagini nelle directory di training e test
num_train_images = count_files(train_dir)
num_test_images = count_files(test_dir)

print(f"Total training images: {num_train_images}")
print(f"Total testing images: {num_test_images}")
# Out:
# Total training images: 2147
# Total testing images: 434

# %% [markdown]
# # TRAINING THE MODEL

# %%
import tensorflow as tf 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping

# %%
# Define the callback
weights_dir ="/Users/joshuabrauner/Desktop/weights best model"

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)
best_model_file = os.path.join(weights_dir, "best_model.weights.h5")
checkpoint = ModelCheckpoint(best_model_file,
                             monitor='val_loss',
                             save_weights_only=True,
                             save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# %%
# Define the parameters for image data preprocessing
datagen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    validation_split=0.3, # better for consistency
    shear_range=0.2,
    zoom_range=0.2,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2
)
# Assuming your training images are sorted in subdirectories within 'tiff_kaggle' directory
train_directory = '/Users/joshuabrauner/Desktop/Train2'

# Define the training generator
train_generator = datagen.flow_from_directory(
    directory=train_directory,  # path to the directory with training data
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
    color_mode='grayscale',
    subset='training'  # set as training data
)

# Define the validation generator
validation_generator = datagen.flow_from_directory(
    directory=train_directory,  # path to the directory with training data
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
    color_mode='grayscale',
    subset='validation'  # set as validation data
)
# Out:
# Found 1449 images belonging to 4 classes.
# Found 619 images belonging to 4 classes.

# %%
# Add the callback to your fit function
history = model.fit(
    train_generator,
    epochs=100,
    validation_data=validation_generator,
    callbacks=[reduce_lr, checkpoint, early_stopping]
)
# Out:
# Epoch 1/100
# /Users/joshuabrauner/Library/Python/3.9/lib/python/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 289ms/step - accuracy: 0.3430 - auc: 0.5584 - loss: 4.0908 - precision: 0.2811 - recall: 0.0858 - val_accuracy: 0.4216 - val_auc: 0.6768 - val_loss: 1.9924 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 255ms/step - accuracy: 0.4146 - auc: 0.6362 - loss: 1.9275 - precision: 0.5318 - recall: 0.0450 - val_accuracy: 0.4216 - val_auc: 0.6937 - val_loss: 1.8137 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 288ms/step - accuracy: 0.4185 - auc: 0.6858 - loss: 1.7451 - precision: 0.6441 - recall: 0.1164 - val_accuracy: 0.4216 - val_auc: 0.7352 - val_loss: 1.6848 - val_precision: 0.4823 - val_recall: 0.4184 - learning_rate: 0.0010
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 306ms/step - accuracy: 0.5182 - auc: 0.7789 - loss: 1.4897 - precision: 0.7147 - recall: 0.3411 - val_accuracy: 0.6494 - val_auc: 0.8877 - val_loss: 1.2389 - val_precision: 0.7500 - val_recall: 0.5816 - learning_rate: 0.0010
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 291ms/step - accuracy: 0.6355 - auc: 0.8824 - loss: 1.1892 - precision: 0.7717 - recall: 0.5593 - val_accuracy: 0.6543 - val_auc: 0.9047 - val_loss: 1.0803 - val_precision: 0.7576 - val_recall: 0.6058 - learning_rate: 0.0010
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 311ms/step - accuracy: 0.6447 - auc: 0.8616 - loss: 1.2214 - precision: 0.7461 - recall: 0.4946 - val_accuracy: 0.6850 - val_auc: 0.9116 - val_loss: 1.0555 - val_precision: 0.8609 - val_recall: 0.5800 - learning_rate: 0.0010
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 283ms/step - accuracy: 0.6701 - auc: 0.8850 - loss: 1.0975 - precision: 0.7877 - recall: 0.5452 - val_accuracy: 0.7512 - val_auc: 0.9239 - val_loss: 1.0081 - val_precision: 0.8969 - val_recall: 0.5622 - learning_rate: 0.0010
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 290ms/step - accuracy: 0.6935 - auc: 0.8983 - loss: 1.0328 - precision: 0.7910 - recall: 0.5526 - val_accuracy: 0.7544 - val_auc: 0.9257 - val_loss: 0.9483 - val_precision: 0.8600 - val_recall: 0.5557 - learning_rate: 0.0010
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 281ms/step - accuracy: 0.7315 - auc: 0.9202 - loss: 0.9229 - precision: 0.8225 - recall: 0.6090 - val_accuracy: 0.7771 - val_auc: 0.9315 - val_loss: 0.9046 - val_precision: 0.8750 - val_recall: 0.6333 - learning_rate: 0.0010
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 260ms/step - accuracy: 0.7367 - auc: 0.9201 - loss: 0.9116 - precision: 0.8264 - recall: 0.6281 - val_accuracy: 0.7496 - val_auc: 0.9317 - val_loss: 0.8692 - val_precision: 0.8330 - val_recall: 0.6365 - learning_rate: 0.0010
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 266ms/step - accuracy: 0.7495 - auc: 0.9289 - loss: 0.8583 - precision: 0.8301 - recall: 0.6588 - val_accuracy: 0.7722 - val_auc: 0.9404 - val_loss: 0.8311 - val_precision: 0.8422 - val_recall: 0.6381 - learning_rate: 0.0010
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 247ms/step - accuracy: 0.7749 - auc: 0.9352 - loss: 0.8268 - precision: 0.8206 - recall: 0.6959 - val_accuracy: 0.6834 - val_auc: 0.9041 - val_loss: 0.9996 - val_precision: 0.7271 - val_recall: 0.6284 - learning_rate: 0.0010
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 257ms/step - accuracy: 0.7347 - auc: 0.9208 - loss: 0.8911 - precision: 0.7950 - recall: 0.6452 - val_accuracy: 0.7835 - val_auc: 0.9459 - val_loss: 0.7655 - val_precision: 0.8355 - val_recall: 0.7302 - learning_rate: 0.0010
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 255ms/step - accuracy: 0.7882 - auc: 0.9436 - loss: 0.7731 - precision: 0.8286 - recall: 0.7257 - val_accuracy: 0.7464 - val_auc: 0.9223 - val_loss: 0.8782 - val_precision: 0.7944 - val_recall: 0.6931 - learning_rate: 0.0010
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 258ms/step - accuracy: 0.7596 - auc: 0.9288 - loss: 0.8542 - precision: 0.8202 - recall: 0.6779 - val_accuracy: 0.7981 - val_auc: 0.9451 - val_loss: 0.7946 - val_precision: 0.8775 - val_recall: 0.7060 - learning_rate: 0.0010
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 259ms/step - accuracy: 0.8059 - auc: 0.9551 - loss: 0.6994 - precision: 0.8352 - recall: 0.7521 - val_accuracy: 0.8223 - val_auc: 0.9591 - val_loss: 0.7041 - val_precision: 0.8606 - val_recall: 0.7383 - learning_rate: 0.0010
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 331ms/step - accuracy: 0.8091 - auc: 0.9536 - loss: 0.7069 - precision: 0.8379 - recall: 0.7688 - val_accuracy: 0.8110 - val_auc: 0.9553 - val_loss: 0.7187 - val_precision: 0.8481 - val_recall: 0.7577 - learning_rate: 0.0010
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 17s 355ms/step - accuracy: 0.7992 - auc: 0.9541 - loss: 0.6961 - precision: 0.8436 - recall: 0.7714 - val_accuracy: 0.7851 - val_auc: 0.9528 - val_loss: 0.7143 - val_precision: 0.8342 - val_recall: 0.7399 - learning_rate: 0.0010
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 296ms/step - accuracy: 0.8104 - auc: 0.9558 - loss: 0.6941 - precision: 0.8491 - recall: 0.7562 - val_accuracy: 0.8207 - val_auc: 0.9539 - val_loss: 0.6987 - val_precision: 0.8496 - val_recall: 0.7754 - learning_rate: 0.0010
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 265ms/step - accuracy: 0.8338 - auc: 0.9569 - loss: 0.6879 - precision: 0.8569 - recall: 0.7859 - val_accuracy: 0.8368 - val_auc: 0.9701 - val_loss: 0.6176 - val_precision: 0.8750 - val_recall: 0.8029 - learning_rate: 0.0010
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.8326 - auc: 0.9654 - loss: 0.6314 - precision: 0.8624 - recall: 0.8161 - val_accuracy: 0.8530 - val_auc: 0.9686 - val_loss: 0.6241 - val_precision: 0.8774 - val_recall: 0.8094 - learning_rate: 0.0010
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 271ms/step - accuracy: 0.8491 - auc: 0.9640 - loss: 0.6409 - precision: 0.8748 - recall: 0.8226 - val_accuracy: 0.8417 - val_auc: 0.9696 - val_loss: 0.6050 - val_precision: 0.8666 - val_recall: 0.8078 - learning_rate: 0.0010
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 271ms/step - accuracy: 0.8287 - auc: 0.9677 - loss: 0.6108 - precision: 0.8495 - recall: 0.8116 - val_accuracy: 0.8158 - val_auc: 0.9565 - val_loss: 0.6894 - val_precision: 0.8362 - val_recall: 0.7916 - learning_rate: 0.0010
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 257ms/step - accuracy: 0.8322 - auc: 0.9597 - loss: 0.6773 - precision: 0.8540 - recall: 0.8003 - val_accuracy: 0.8417 - val_auc: 0.9711 - val_loss: 0.6019 - val_precision: 0.8774 - val_recall: 0.8094 - learning_rate: 0.0010
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 252ms/step - accuracy: 0.8455 - auc: 0.9698 - loss: 0.5942 - precision: 0.8699 - recall: 0.8188 - val_accuracy: 0.8691 - val_auc: 0.9798 - val_loss: 0.5281 - val_precision: 0.8900 - val_recall: 0.8498 - learning_rate: 0.0010
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 242ms/step - accuracy: 0.8431 - auc: 0.9656 - loss: 0.6226 - precision: 0.8629 - recall: 0.8182 - val_accuracy: 0.8627 - val_auc: 0.9754 - val_loss: 0.5622 - val_precision: 0.8875 - val_recall: 0.8288 - learning_rate: 0.0010
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 253ms/step - accuracy: 0.8683 - auc: 0.9703 - loss: 0.5854 - precision: 0.8839 - recall: 0.8494 - val_accuracy: 0.8691 - val_auc: 0.9755 - val_loss: 0.5533 - val_precision: 0.8895 - val_recall: 0.8449 - learning_rate: 0.0010
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 256ms/step - accuracy: 0.8601 - auc: 0.9719 - loss: 0.5790 - precision: 0.8897 - recall: 0.8372 - val_accuracy: 0.8643 - val_auc: 0.9702 - val_loss: 0.6034 - val_precision: 0.8947 - val_recall: 0.8239 - learning_rate: 0.0010
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 268ms/step - accuracy: 0.8595 - auc: 0.9728 - loss: 0.5746 - precision: 0.8867 - recall: 0.8313 - val_accuracy: 0.8659 - val_auc: 0.9776 - val_loss: 0.5484 - val_precision: 0.8885 - val_recall: 0.8498 - learning_rate: 0.0010
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 250ms/step - accuracy: 0.8834 - auc: 0.9782 - loss: 0.5236 - precision: 0.8959 - recall: 0.8700 - val_accuracy: 0.8675 - val_auc: 0.9759 - val_loss: 0.5372 - val_precision: 0.8802 - val_recall: 0.8546 - learning_rate: 0.0010
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 298ms/step - accuracy: 0.9006 - auc: 0.9818 - loss: 0.4900 - precision: 0.9159 - recall: 0.8849 - val_accuracy: 0.8288 - val_auc: 0.9604 - val_loss: 0.6477 - val_precision: 0.8484 - val_recall: 0.8045 - learning_rate: 0.0010
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.8659 - auc: 0.9777 - loss: 0.5280 - precision: 0.8824 - recall: 0.8461 - val_accuracy: 0.8643 - val_auc: 0.9757 - val_loss: 0.5527 - val_precision: 0.8773 - val_recall: 0.8433 - learning_rate: 0.0010
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 12s 255ms/step - accuracy: 0.8905 - auc: 0.9805 - loss: 0.5050 - precision: 0.9052 - recall: 0.8743 - val_accuracy: 0.8239 - val_auc: 0.9524 - val_loss: 0.7033 - val_precision: 0.8361 - val_recall: 0.7997 - learning_rate: 0.0010
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.8806 - auc: 0.9721 - loss: 0.5590 - precision: 0.8954 - recall: 0.8547 - val_accuracy: 0.8514 - val_auc: 0.9724 - val_loss: 0.5687 - val_precision: 0.8712 - val_recall: 0.8304 - learning_rate: 0.0010
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 13s 274ms/step - accuracy: 0.8847 - auc: 0.9781 - loss: 0.5160 - precision: 0.8972 - recall: 0.8684 - val_accuracy: 0.8740 - val_auc: 0.9747 - val_loss: 0.5412 - val_precision: 0.8787 - val_recall: 0.8546 - learning_rate: 0.0010

# %%
model.save("CNN_team5.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Plot the history
# Extracting the loss on the validation set
val_loss = history.history['val_loss']
loss = history.history['loss']

# Extracting the number of epochs
epochs = range(1, len(val_loss) + 1)

# Plotting
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
plt.plot(epochs, val_loss, 'b-', label='Validation Loss')
plt.plot(epochs, loss, 'r-', label='Loss')
plt.title('Loss vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#accuracy
val_accuracy = history.history['val_accuracy']
accuracy = history.history['accuracy']

plt.figure(figsize=(15, 5))
plt.plot(epochs,val_accuracy , 'b-', label='Validation Accuracy')
plt.plot(epochs, accuracy, 'r-', label='Accuracy')
plt.title('Accuracy vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (15, 5))
plt.plot(history.history['accuracy'], "darkgreen", label= "accuracy")
plt.plot(history.history['recall'], "darkred", label= "recall")
plt.plot(history.history['precision'], "darkblue", label= "precision")
plt.plot(history.history['auc'], "darkorange", label= "auc")
plt.xlabel('Epoch')
plt.legend()

# %%
plt.figure(figsize = (15, 5))
plt.plot(history.history['loss'], "darkgreen", label= "accuracy")
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# ## MODEL EVALUATION

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

test_datagen = ImageDataGenerator(rescale=1./255)  # Assumi che il preprocessing sia solo una normalizzazione

test_generator = test_datagen.flow_from_directory(
    "/Users/joshuabrauner/Desktop/Test2",  # Percorso della cartella contenente le immagini di test
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    color_mode='grayscale',  # Assumi che le immagini siano in scala di grigi
    shuffle=False)
# Out:
# Found 433 images belonging to 4 classes.

# %%
# Evaluation of the model on the test set
results = model.evaluate(test_generator)
test_loss = results[0]  # Loss is the first value
test_acc = results[1]  # Accuracy is the second value

# Assuming you have additional metrics beyond accuracy, you can capture them like this:
test_auc = results[2]  # AUC is the third value
test_fn = results[3]  # False Negatives is the fourth value
test_fp = results[4]  # False Positives is the fifth value

# Now, you can print them all
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_acc}")
print(f"Test AUC: {test_auc}")
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8438 - auc: 0.9587 - loss: 0.6960 - precision: 0.8577 - recall: 0.8319
# Test Loss: 0.6770642995834351
# Test Accuracy: 0.8475750684738159
# Test AUC: 0.8578199148178101

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# Assuming test_generator is properly defined and is the test data generator
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# The true class labels
true_classes = test_generator.classes

# Get the class labels from the generator (for a more readable classification report)
class_labels = list(test_generator.class_indices.keys())

# Calculate the confusion matrix
print(confusion_matrix(true_classes, predicted_classes))

# Calculate the classification report
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step
# [[ 74   0   1   1]
#  [  4  41   4  21]
#  [ 20   0  84   1]
#  [ 11   0   3 168]]
#                 precision    recall  f1-score   support
#
# advertisements       0.68      0.97      0.80        76
#          email       1.00      0.59      0.74        70
#    handwritten       0.91      0.80      0.85       105
#         resume       0.88      0.92      0.90       182
#
#       accuracy                           0.85       433
#      macro avg       0.87      0.82      0.82       433
#   weighted avg       0.87      0.85      0.85       433

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Assuming 'true_classes' and 'predicted_classes' are available
cm = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(8, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## Continue with evaluation but first reset test generator

# %%
# Reset the test_generator before making predictions
test_generator.reset()

# %%
# Reset the test_generator before making predictions to ensure alignment
test_generator.reset()

# Predict the classes with the model
predictions = model.predict(test_generator, verbose=1)

# Get the class indices with the highest probability for each prediction
predicted_classes_indices = np.argmax(predictions, axis=1)

# Get the true class indices from the generator
true_classes = test_generator.classes

# Get the class labels for a better readability in the classification report
class_labels = list(test_generator.class_indices.keys())

# Compare predicted and true class indices
count_true = np.sum(predicted_classes_indices == true_classes)
count_false = len(true_classes) - count_true

# Calculate the error rate
error_rate = count_false / len(true_classes)

# Print the results
print("Number of successes:", count_true)
print("Number of errors:", count_false)
print("Error rate:", error_rate)
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step
# Number of successes: 367
# Number of errors: 66
# Error rate: 0.15242494226327943

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_sample_predictions(generator, predicted_classes, class_labels, n=10):
    """ Plot a random selection of images with their predictions and true labels. """
    images, true_labels = next(generator)
    if len(images) > len(predicted_classes):
        raise ValueError("The number of predicted classes does not match the number of loaded images")
    
    indices = np.random.choice(len(images), n, replace=False)
    plt.figure(figsize=(2*n, 4))
    for i, index in enumerate(indices):
        # Debugging output
        print(f"Index: {index}, Predicted: {predicted_classes[index]}, True: {true_labels[index]}")
        pred_label = class_labels[predicted_classes[index]]
        true_label = class_labels[np.argmax(true_labels[index])]
        
        plt.subplot(1, n, i + 1)
        plt.imshow(images[index])
        plt.title(f'Pred: {pred_label}\nTrue: {true_label}')
        plt.axis('off')
    plt.show()

# Example usage
plot_sample_predictions(test_generator, predicted_classes, class_labels)
# Out:
# Index: 8, Predicted: 0, True: [1. 0. 0. 0.]
# Index: 5, Predicted: 0, True: [1. 0. 0. 0.]
# Index: 13, Predicted: 0, True: [1. 0. 0. 0.]
# Index: 12, Predicted: 0, True: [1. 0. 0. 0.]
# Index: 11, Predicted: 0, True: [1. 0. 0. 0.]
# Index: 14, Predicted: 0, True: [1. 0. 0. 0.]
# Index: 10, Predicted: 0, True: [1. 0. 0. 0.]
# Index: 1, Predicted: 0, True: [1. 0. 0. 0.]
# Index: 4, Predicted: 0, True: [1. 0. 0. 0.]
# Index: 2, Predicted: 0, True: [1. 0. 0. 0.]

# %%
# Make sure the generator does not shuffle data to maintain the order
test_generator.shuffle = False
test_generator.batch_size = 1  # Set batch size to 1 to get predictions one by one

# Reset the generator to be sure to start from the beginning
test_generator.reset()

# Predict the classes with the model for the number of samples you want
# If you want to test a subset, replace 'len(test_generator)' with the number of samples you want
predictions = model.predict(test_generator, steps=len(test_generator), verbose=1)

# Get the class indices with the highest probability for each prediction
predicted_classes_indices = np.argmax(predictions, axis=1)

# Get the true class indices from the generator
true_classes = test_generator.classes

# Get the class labels for a better readability
class_labels = list(test_generator.class_indices.keys())

# Iterate over each prediction and true class
for i, (pred_idx, true_idx) in enumerate(zip(predicted_classes_indices, true_classes)):
    # Get the predicted label and true label using their indices
    predicted_label = class_labels[pred_idx]
    true_label = class_labels[true_idx]
    
    # Determine if the prediction is correct
    result = "True" if predicted_label == true_label else "False"
    
    # Print the information
    print(f"Prediction: {predicted_label} | Real class: {true_label} | Result: {result}")
# Out:
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: resume | Real class: advertisements | Result: False
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: handwritten | Real class: advertisements | Result: False
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: handwritten | Real class: advertisements | Result: False
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: advertisements | Real class: advertisements | Result: True
# Prediction: resume | Real class: email | Result: False
# Prediction: resume | Real class: email | Result: False
# Prediction: advertisements | Real class: email | Result: False
# Prediction: email | Real class: email | Result: True
# Prediction: resume | Real class: email | Result: False
# Prediction: resume | Real class: email | Result: False
# Prediction: resume | Real class: email | Result: False
# Prediction: email | Real class: email | Result: True
# Prediction: resume | Real class: email | Result: False
# Prediction: resume | Real class: email | Result: False
# Prediction: email | Real class: email | Result: True
# Prediction: resume | Real class: email | Result: False
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: resume | Real class: email | Result: False
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: resume | Real class: email | Result: False
# Prediction: resume | Real class: email | Result: False
# Prediction: resume | Real class: email | Result: False
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: handwritten | Real class: email | Result: False
# Prediction: email | Real class: email | Result: True
# Prediction: handwritten | Real class: email | Result: False
# Prediction: email | Real class: email | Result: True
# Prediction: resume | Real class: email | Result: False
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: advertisements | Real class: email | Result: False
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: resume | Real class: email | Result: False
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: resume | Real class: email | Result: False
# Prediction: email | Real class: email | Result: True
# Prediction: handwritten | Real class: email | Result: False
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: email | Real class: email | Result: True
# Prediction: resume | Real class: email | Result: False
# Prediction: email | Real class: email | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: advertisements | Real class: handwritten | Result: False
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: advertisements | Real class: handwritten | Result: False
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: advertisements | Real class: handwritten | Result: False
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: advertisements | Real class: handwritten | Result: False
# Prediction: advertisements | Real class: handwritten | Result: False
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: advertisements | Real class: handwritten | Result: False
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: advertisements | Real class: handwritten | Result: False
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: advertisements | Real class: handwritten | Result: False
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: advertisements | Real class: handwritten | Result: False
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: advertisements | Real class: handwritten | Result: False
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: advertisements | Real class: handwritten | Result: False
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: advertisements | Real class: handwritten | Result: False
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: advertisements | Real class: handwritten | Result: False
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: advertisements | Real class: handwritten | Result: False
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: handwritten | Result: True
# Prediction: handwritten | Real class: resume | Result: False
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: advertisements | Real class: resume | Result: False
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: handwritten | Real class: resume | Result: False
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: advertisements | Real class: resume | Result: False
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: advertisements | Real class: resume | Result: False
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
# Prediction: resume | Real class: resume | Result: True
